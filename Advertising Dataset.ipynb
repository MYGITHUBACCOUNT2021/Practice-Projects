# %% [markdown]
# Importing numpy and pandas liaberary

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading Dataset

# %%
data = pd.read_csv(r"C:\Users\acer\Desktop\MJ practice\MACHINE LEARNING\Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# checking columns

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# As per above observation we have total 5 columns

# %%
data.shape

# %% [markdown]
# As per above observation we have 200 rows and 5 columns

# %% [markdown]
# Checking missing values

# %%
data.isnull().sum()

# %% [markdown]
# As per above observation  we dont have any missing values.

# %% [markdown]
# As per above observation Unnamed: 0  column is not making any sense in our dataset hence dropping this column.

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.scatterplot(x='TV',y='sales',data=data)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %% [markdown]
# As per above observation we an see that points are more or less compact and not scattered far away
#
# We can also see that If the TV advertising cost increases the sales also increases.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='radio',y='sales',data=data)
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %% [markdown]
# As per above observation we can see that points are little more scattered than  the "TV vs sales"

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='newspaper',y='sales',data=data)
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# As per above observation we can see that points are way more scattered than  the "TV vs sales" and "radio vs sales"

# %% [markdown]
# Checking Correlation

# %%
data.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),annot=True,linewidths=0.5,linecolor='r',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above observation  TV has 78% positive correlation with Taget column, radio has 58% positive correlation with Taget column, newspaper has 23 % negetive correlation with Taget column
#
# Minimum correlation : newspaper
#
# Maximum correlation : TV

# %% [markdown]
# Describe dataset

# %%
data.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Outcome of descrive function are mention below:
#
# Total rows: 200
#
# Total columns: 5
#
#
#
#
#
#
#
# TV
#
#
#
# mean:147.042500
#
# std: 85.854236
#
# min:0.700000
#
# median:149.750000
#
# max:296.400000
#
#
#
#
#
#
#
#
# radio
#
#
#
#
# mean:23.264000
#
# std:14.846809
#
# min:0.000000
#
# median:22.900000
#
# max:49.600000
#
#
#
#
#
#
#
#
# newspaper
#
#
#
# mean:30.554000
#
# std:21.778621
#
# min:0.300000
#
# median:25.750000
#
# max:114.000000

# %% [markdown]
# Checking Outlier

# %%
data.columns.values
# Out:
# array(['TV', 'radio', 'newspaper', 'sales'], dtype=object)

# %%
collist=data.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=data[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# As per above observation columns like  [ 'TV', 'radio','sales'] have no ouliers and  'newspaper' column has 2 outliers.

# %% [markdown]
# Checking Skewness

# %%
data.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %% [markdown]
# Good value for skewness is  between -0.5 and 0.5
#
# As per above observation below columns are not falling in between -0.5 and 0.5 range
#
# TV          -0.069853
#
#
# radio        0.094175
#
#
# newspaper    0.894720

# %% [markdown]
# Normal Distribution Curve

# %%
sns.distplot(data['TV'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %% [markdown]
# As per above observation we can see that Normal distribution shows that data is skewed

# %%
sns.distplot(data['radio'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# As per above observation we can see that Normal distribution shows that data is skewed

# %%
sns.distplot(data['radio'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# As per above observation we can see that Normal distribution shows that data is skewed

# %% [markdown]
# Removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(data))
z.shape
# Out:
# (200, 4)

# %%
# np.where returns index where data points are outliers
threshold=3
print(np.where(z>3))
# Out:
# (array([ 16, 101], dtype=int32), array([2, 2], dtype=int32))

# %%
# Extracting the data points those are in the range(-3,3)
data_new = data[(z<3).all(axis=1)]
print(data.shape)
print(data_new.shape)
# Out:
# (200, 4)
# (198, 4)

# %% [markdown]
# Percentage of data loss

# %%
loss_pecentage=(200-198)/200*100
print(loss_pecentage)
# Out:
# 1.0

# %% [markdown]
# Dividing data into features and vectors

# %%
x = data.drop('sales',axis=1)
y=data['sales']

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %% [markdown]
# As per above observation Target column is sucessfully dropped

# %% [markdown]
# Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 9.65731045e-01,  9.74105998e-01,  1.54638667e+00],
#        [-1.15978807e+00,  1.06999587e+00,  7.81145542e-01],
#        [-1.49452256e+00,  1.48849275e+00,  1.54922082e+00],
#        [ 1.08113368e-02,  1.19740515e+00,  1.22869514e+00],
#        [ 3.56328915e-01, -7.95106937e-01,  1.22557900e+00],
#        [-1.61804855e+00,  1.67686220e+00,  1.70711870e+00],
#        [-1.01415862e+00,  6.52498969e-01, -1.31493713e-01],
#        [-3.38815161e-01, -2.05738361e-01, -8.49808016e-01],
#        [-1.61962487e+00, -1.50891372e+00, -2.06366161e+00],
#        [ 5.87680330e-01, -1.45775614e+00, -2.51554226e-01],
#        [-9.20086033e-01, -1.17176232e+00, -9.61872843e-02],
#        [ 7.72328008e-01,  8.06993555e-02, -1.56945649e+00],
#        [-1.40768848e+00,  8.00803899e-01,  1.45153752e+00],
#        [-5.83141790e-01, -1.02965235e+00, -1.21783059e+00],
#        [ 6.40698435e-01,  6.58959305e-01,  8.13336346e-01],
#        [ 5.33669355e-01,  1.60165311e+00,  1.04938720e+00],
# ...

# %% [markdown]
# Splitting Dataset into train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# Trying to fetch the best Random state no. for Training and Testing 
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:-{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracyis:-0.9004898017598606
# At random state 0,the testing accuracyis:-0.8622705409412871
#
#
# At random state 1,the training accuracyis:-0.8928484191625207
# At random state 1,the testing accuracyis:-0.8813481156365954
#
#
# At random state 2,the training accuracyis:-0.911283889599335
# At random state 2,the testing accuracyis:-0.749281400905379
#
#
# At random state 3,the training accuracyis:-0.8891417119379977
# At random state 3,the testing accuracyis:-0.9076591554039943
#
#
# At random state 4,the training accuracyis:-0.8881208737310156
# At random state 4,the testing accuracyis:-0.8991969456211446
#
#
# At random state 5,the training accuracyis:-0.8919592771875673
# At random state 5,the testing accuracyis:-0.8926453652860404
#
#
# At random state 6,the training accuracyis:-0.8882410602970561
# At random state 6,the testing accuracyis:-0.9139671451427486
#
#
# At random state 7,the training accuracyis:-0.8886907715420127
# ...

# %% [markdown]
# As per above observation we are getting best accuracy At random state 980
#
#
# At random state 980,the training accuracyis:-0.8901257174708279
#
# At random state 980,the testing accuracyis:-0.8902838279196383

# %% [markdown]
# Checking  cross validation of the Model

# %%
train_accuracy = r2_score(y_train,pred_train)
test_accuracy = r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score = cross_val_score(lr,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and the accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy})")
    print("\n")
# Out:
# At cross fold2 the cv score is 0.8883858570878582 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# At cross fold3 the cv score is 0.8872975705749305 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# At cross fold4 the cv score is 0.8858466914675982 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# At cross fold5 the cv score is 0.8828514372940433 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# At cross fold6 the cv score is 0.8856907948422629 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# At cross fold7 the cv score is 0.8812735918185304 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)
#
#
# ...

# %% [markdown]
# At cross fold4 the cv score is performing better however the accuracy score for the training and testing is same At all cross fold.
#
# At cross fold4 the cv score is 0.8858466914675982 and the accuracy score for training is -0.8795204962460725 and accuracy for testing is -0.7637645426085313)

# %% [markdown]
# Building Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=980)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
lr_pred = lr.predict(x_test)
print(r2_score(lr_pred,y_test))
# Out:
# 0.8712146861925001

# %%
r = Ridge()
r.fit(x_train,y_train)
r_pred = r.predict(x_test)
print(r2_score(y_test,r_pred))
# Out:
# 0.8897463390251736

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
rf_pred = rf.predict(x_test)
print(r2_score(y_test,rf_pred))
# Out:
# 0.9813429440313483

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
svr_pred = svr.predict(x_test)
print(r2_score(y_test,svr_pred))
# Out:
# 0.9321821795883287

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt_pred = dt.predict(x_test)
print(r2_score(y_test,dt_pred))
# Out:
# 0.9639458661843924

# %% [markdown]
# cross validation

# %%
# Getting cross validation for LinearRegression

cross_val_score(lr,x,y,cv=4).mean()
# Out:
# 0.8858466914675982

# %%
# Getting cross validation for Ridge

cross_val_score(r,x,y,cv=4).mean()
# Out:
# 0.8858391765390456

# %%
# Getting cross validation for RandomForestRegressor

cross_val_score(rf,x,y,cv=4).mean()
# Out:
# 0.977381343642457

# %%
# Getting cross validation for SVR

cross_val_score(svr,x,y,cv=4).mean()
# Out:
# 0.9016716060517452

# %%
# Getting cross validation for DecisionTreeRegressor

cross_val_score(dt,x,y,cv=4).mean()
# Out:
# 0.9407858211996885

# %%
# model	   r2           cv              Difference
# lr	0.871214686	   0.885846691	    0.014632005
# r	    0.889746339	   0.885839177	    -0.003907162
#rf	    0.981342944	   0.977381344	    -0.0039616
#svr	0.93218218	   0.901671606	    -0.030510574
#dt	    0.963945866	   0.940785821	    -0.023160045


# As per above observation Random Forest Regressor is doing better hence we will go with RandomForestRegressor.

# %% [markdown]
# Hyperparameter tuning for RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
parameter = {'n_estimators':[1000],
             'criterion':['squared_error','absolute_error','poisson'],
             'max_depth':np.arange(2,10),
             'max_features':['auto','sqrt','log2']}

# %%
gsc = GridSearchCV(estimator=rf,param_grid=parameter)
gsc.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [1000]})

# %%
gsc.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 9,
#  'max_features': 'auto',
#  'n_estimators': 1000}

# %%
Final_advertising_model = RandomForestRegressor(criterion='absolute_error',max_depth=8,max_features='auto',n_estimators=1000)
Final_advertising_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=8,
#                       n_estimators=1000)

# %%
Final_advertising_model_pd = Final_advertising_model.predict(x_test)
print(r2_score(Final_advertising_model_pd,y_test))
# Out:
# 0.981423326015914

# %% [markdown]
# save the model

# %%
import joblib
joblib.dump(Final_advertising_model,"Final_ADVERTISING_DATA_model")
# Out:
# ['Final_ADVERTISING_DATA_model']
